# %% [markdown]
# # 26 ago 2018

# %%
import pandas as pd
import numpy as np

# %%
from utils.camara_obter_dados import obter_detalhes
from utils.camara_obter_dados import map_proposicoes
from utils.dataframe_to_database import dataframe_to_database

# %%
colunas_dataframe_tema = [
    'id',
    'idCategoria',
    'titulo',
    'descricao',
    'origemImprensa',
    'idProposicaoCamara',
    'idVotacaoProposicaoCamara',
    'idProposicaoSenado',
    'idVotacaoProposicaoSenado',
]

colunas_tabela_tema = [
    'id',
    'tema_categoria_id',
    'titulo',
    'descricao',
    'origem_imprensa',
    'camara_proposicao_id',
    'camara_proposicao_votacao_id',
    'senado_proposicao_id',
    'senado_proposicao_votacao_id',
]

colunas_dataframe_tema_link = [
    'idTema',
    'titulo',
    'url',
    'shortUrl',
]

colunas_tabela_tema_link = [
    'tema_id',
    'titulo',
    'url',
    'short_url',
]

# %% [markdown]
# ## Educação - Escola sem Partido

# %%
df_tema = pd.DataFrame(
    data=[{
        'id': 10,
        'idCategoria': 7,
        'titulo': 'Escola sem Partido',
        'descricao': 'Movimento que diz representar pais e estudantes contrários ao que chamam de “doutrinação ideológica” nas salas de aula brasileiras. No site oficial, o movimento diz se preocupar "com o grau de contaminação político-ideológica das escolas brasileiras", e afirma que "um exército organizado de militantes travestidos de professores prevalece-se da liberdade de cátedra e da cortina de segredo das salas de aula para impingir-lhes a sua própria visão de mundo".',
        'origemImprensa': True,
        'idProposicaoCamara': None,
        'idVotacaoProposicaoCamara': None,
        'idProposicaoSenado': None,
        'idVotacaoProposicaoSenado': None,
    }],
    columns=colunas_dataframe_tema
)
dataframe_to_database(
    dataframe=df_tema,
    tabela='tema',
    colunas_tabela=colunas_tabela_tema,
    colunas_dataframe=colunas_dataframe_tema
)
df_links = pd.DataFrame(
  data=[
      {
          'idTema': 10,
          'titulo': 'Escola sem Partido: entenda a polêmica em torno do movimento e seus projetos de lei | Educação | G1',
          'url': 'https://g1.globo.com/educacao/noticia/entenda-a-polemica-em-torno-do-escola-sem-partido.ghtml',
          'shortUrl': 'https://glo.bo/2wcredR',
      },
      {
          'idTema': 10,
          'titulo': 'Escola sem Partido: entenda o que é movimento que divide opiniões na Educação | EBC',
          'url': 'http://www.ebc.com.br/educacao/2016/07/o-que-e-o-escola-sem-partido',
          'shortUrl': 'http://bit.ly/2Ls7ibt',
      },
      {
          'idTema': 10,
          'titulo': 'O mapa que registra projetos da Escola sem Partido no país - Nexo Jornal',
          'url': 'https://www.nexojornal.com.br/expresso/2017/11/12/O-mapa-que-registra-projetos-da-Escola-sem-Partido-no-pa%C3%ADs',
          'shortUrl': 'http://bit.ly/2P6tzOf',
      },
  ],
  columns=colunas_dataframe_tema_link
)
dataframe_to_database(
    dataframe=df_links,
    tabela='tema_link',
    colunas_tabela=colunas_tabela_tema_link,
    colunas_dataframe=colunas_dataframe_tema_link
)
# Out:
# 3 de 3

# %% [markdown]
# ## Energia - Fim do Regime de Partilha

# %% [markdown]
# http://www2.camara.leg.br/camaranoticias/noticias/ECONOMIA/517342-CAMARA-APROVA-FIM-DA-PARTICIPACAO-OBRIGATORIA-DA-PETROBRAS-NO-PRE-SAL.html
#
# http://www.camara.gov.br/proposicoesWeb/fichadetramitacao?idProposicao=2078295

# %%
# 28 ago 2018

df_i = obter_detalhes(
    endpoint='/proposicoes',
    id=2078295,
    map_response=map_proposicoes
)

# %%
df_i
# Out:
#         id                                                uri siglaTipo  \
# 0  2078295  https://dadosabertos.camara.leg.br/api/v2/prop...        PL
#
#    idTipo  numero   ano                                             ementa  \
# 0     139    4567  2016  Altera a Lei nº 12.351, de 22 de dezembro de 2...
#
#    dataApresentacao uriOrgaoNumerador uriUltimoRelator      ...       \
# 0  2016-02-25T18:12              None             None      ...
#
#     descricaoTipo  ementaDetalhada  \
# 0  Projeto de Lei
#
#                                             keywords uriPropPrincipal  \
# 0  Alteração, Lei do Pré-Sal, Petróleo Brasileiro...             None
#
#   uriPropAnterior uriPropPosterior  \
# 0            None             None
#
#                                       urlInteiroTeor urnFinal  texto  \
# 0  http://www.camara.gov.br/proposicoesWeb/prop_m...     None   None
#
#   justificativa
# 0          None
#
# [1 rows x 32 columns]

# %%
df_i[[
    'id',
    'dataApresentacao',
    'statusProposicao_dataHora',
    'statusProposicao_descricaoTramitacao',
    'statusProposicao_descricaoSituacao',
    'keywords',
    'urlInteiroTeor'
]]
# Out:
#         id  dataApresentacao statusProposicao_dataHora  \
# 0  2078295  2016-02-25T18:12          2016-12-05T00:00
#
#   statusProposicao_descricaoTramitacao statusProposicao_descricaoSituacao  \
# 0            Remessa ao Senado Federal     Transformado em Norma Jurídica
#
#                                             keywords  \
# 0  Alteração, Lei do Pré-Sal, Petróleo Brasileiro...
#
#                                       urlInteiroTeor
# 0  http://www.camara.gov.br/proposicoesWeb/prop_m...

# %%
dataframe_to_database(
    dataframe=df_i,
    tabela='camara_proposicao_detalhada',
    colunas_tabela=[
        'id',
        'data_apresentacao',
        'data_ultimo_status',
        'descricao_tramitacao',
        'descricao_situacao',
        'keywords',
        'url_integra'
    ],
    colunas_dataframe=[
        'id',
        'dataApresentacao',
        'statusProposicao_dataHora',
        'statusProposicao_descricaoTramitacao',
        'statusProposicao_descricaoSituacao',
        'keywords',
        'urlInteiroTeor'
    ]
)
# Out:
# 1 de 1

# %%
df_tema = pd.DataFrame(
    data=[{
        'id': 11,
        'idCategoria': 2,
        'titulo': 'Fim do Regime de Partilha',
        'descricao': 'Pelo regime de partilha de produção, instituído em 2010, os concessionários remuneram o governo com uma parcela do chamado óleo-lucro (volume que sobra após o desconto dos barris equivalentes aos custos do projeto). Pelo regime de concessão, ganha a licitação a empresa que pagar mais ao governo pelo direito de explorar a área.',
        'origemImprensa': False,
        'idProposicaoCamara': 2078295,
        'idVotacaoProposicaoCamara': 7197,
        'idProposicaoSenado': None,
        'idVotacaoProposicaoSenado': None,
    }],
    columns=colunas_dataframe_tema
)
dataframe_to_database(
    dataframe=df_tema,
    tabela='tema',
    colunas_tabela=colunas_tabela_tema,
    colunas_dataframe=colunas_dataframe_tema
)
df_links = pd.DataFrame(
  data=[
      {
          'idTema': 11,
          'titulo': 'Os regimes de concessão e de partilha - ANP',
          'url': 'http://rodadas.anp.gov.br/pt/entenda-as-rodadas/os-regimes-de-concessao-e-de-partilha',
          'shortUrl': 'http://bit.ly/2MAADWy',
      },
      {
          'idTema': 11,
          'titulo': 'O que é o ‘petróleo da União’ recém-tirado do pré-sal - Nexo Jornal',
          'url': 'https://www.nexojornal.com.br/expresso/2018/04/09/O-que-%C3%A9-o-%E2%80%98petr%C3%B3leo-da-Uni%C3%A3o%E2%80%99-rec%C3%A9m-tirado-do-pr%C3%A9-sal',
          'shortUrl': 'http://bit.ly/2NkQg0G',
      },
      {
          'idTema': 11,
          'titulo': 'Discussão sobre fim do regime de partilha de petróleo ganha espaço no governo',
          'url': 'https://www.terra.com.br/economia/discussao-sobre-fim-do-regime-de-partilha-de-petroleo-ganha-espaco-no-governo,6ddc1d4619b6940f20f6b3e9e62bb2b759pfdd7k.html',
          'shortUrl': 'http://bit.ly/2MwmjP8',
      },
  ],
  columns=colunas_dataframe_tema_link
)
dataframe_to_database(
    dataframe=df_links,
    tabela='tema_link',
    colunas_tabela=colunas_tabela_tema_link,
    colunas_dataframe=colunas_dataframe_tema_link
)
# Out:
# 3 de 3

# %% [markdown]
# ## Energia - Privatização da Eletrobrás

# %%
df_tema = pd.DataFrame(
    data=[{
        'id': 12,
        'idCategoria': 2,
        'titulo': 'Privatização da Eletrobrás',
        'descricao': 'Atualmente, a União é dona de 51% das ações com direito a voto. Logo, tem o controle sobre as principais decisões. O projeto de lei estabelece a ampliação do capital social ou, em outras palavras, o aumento do número de ações. O que a Eletrobras vai fazer é criar novas ações e vendê-las ao mercado. O dinheiro arrecadado vai para a empresa, o que a tornará maior. O governo, assim como os outros atuais acionistas, fica com o mesmo número de ações.',
        'origemImprensa': True,
        'idProposicaoCamara': None,
        'idVotacaoProposicaoCamara': None,
        'idProposicaoSenado': None,
        'idVotacaoProposicaoSenado': None,
    }],
    columns=colunas_dataframe_tema
)
dataframe_to_database(
    dataframe=df_tema,
    tabela='tema',
    colunas_tabela=colunas_tabela_tema,
    colunas_dataframe=colunas_dataframe_tema
)
df_links = pd.DataFrame(
  data=[
      {
          'idTema': 12,
          'titulo': 'Por que Temer quer vender a Eletrobras. E quais os efeitos da medida - Nexo Jornal',
          'url': 'https://www.nexojornal.com.br/expresso/2017/08/22/Por-que-Temer-quer-vender-a-Eletrobras.-E-quais-os-efeitos-da-medida',
          'shortUrl': 'http://bit.ly/2BJQM7l',
      },
      {
          'idTema': 12,
          'titulo': 'O que significa privatizar a Eletrobras? - BBC News Brasil',
          'url': 'https://www.bbc.com/portuguese/brasil-41067896',
          'shortUrl': 'https://bbc.in/2NimZE0',
      },
      {
          'idTema': 12,
          'titulo': 'É preciso privatizar a Eletrobras? - Sim e Não - Folha de São Paulo',
          'url': 'http://www.ilumina.org.br/e-preciso-privatizar-a-eletrobras-sim-e-nao-folha-de-sao-paulo/',
          'shortUrl': 'http://bit.ly/2oc4iHe',
      },
  ],
  columns=colunas_dataframe_tema_link
)
dataframe_to_database(
    dataframe=df_links,
    tabela='tema_link',
    colunas_tabela=colunas_tabela_tema_link,
    colunas_dataframe=colunas_dataframe_tema_link
)
# Out:
# 3 de 3

# %% [markdown]
# ## Segurança - Porte de Armas

# %%
df_tema = pd.DataFrame(
    data=[{
        'id': 13,
        'idCategoria': 5,
        'titulo': 'Porte de Armas',
        'descricao': 'Facilitar o acesso a armas de fogo pela população brasileira.',
        'origemImprensa': True,
        'idProposicaoCamara': None,
        'idVotacaoProposicaoCamara': None,
        'idProposicaoSenado': None,
        'idVotacaoProposicaoSenado': None,
    }],
    columns=colunas_dataframe_tema
)
dataframe_to_database(
    dataframe=df_tema,
    tabela='tema',
    colunas_tabela=colunas_tabela_tema,
    colunas_dataframe=colunas_dataframe_tema
)
df_links = pd.DataFrame(
  data=[
      {
          'idTema': 13,
          'titulo': 'Controle de armas de fogo: dados e opiniões sobre o tema no Brasil - Nexo Jornal',
          'url': 'https://www.nexojornal.com.br/especial/2017/02/24/Controle-de-armas-de-fogo-dados-e-opini%C3%B5es-sobre-o-tema-no-Brasil',
          'shortUrl': 'http://bit.ly/2BJUH43',
      },
      {
          'idTema': 13,
          'titulo': 'Apoio a porte de armas cresce no Brasil, o campeão de homicídios | EXAME',
          'url': 'https://exame.abril.com.br/brasil/apoio-a-porte-de-armas-cresce-no-brasil-pais-campeao-de-mortes/',
          'shortUrl': 'https://abr.ai/2obuscQ',
      },
      {
          'idTema': 13,
          'titulo': 'Estatuto do controle de armas de fogo: Solução ou ilusão?',
          'url': 'https://robsonsouto39.jusbrasil.com.br/artigos/266994387/estatuto-do-controle-de-armas-de-fogo-solucao-ou-ilusao',
          'shortUrl': 'http://bit.ly/2BMLJ65',
      },
  ],
  columns=colunas_dataframe_tema_link
)
dataframe_to_database(
    dataframe=df_links,
    tabela='tema_link',
    colunas_tabela=colunas_tabela_tema_link,
    colunas_dataframe=colunas_dataframe_tema_link
)
# Out:
# 3 de 3

# %% [markdown]
# ## Segurança - Redução da Maioridade Penal

# %%
df_tema = pd.DataFrame(
    data=[{
        'id': 14,
        'idCategoria': 5,
        'titulo': 'Redução da Maioridade Penal',
        'descricao': 'Pelo texto proposto, jovens menores de 18 anos, mas maiores de 16 anos, poderão ser condenados pela prática de crimes graves. Hoje, a Constituição diz que só os maiores de 18 podem ser presos.',
        'origemImprensa': True,
        'idProposicaoCamara': None,
        'idVotacaoProposicaoCamara': None,
        'idProposicaoSenado': None,
        'idVotacaoProposicaoSenado': None,
    }],
    columns=colunas_dataframe_tema
)
dataframe_to_database(
    dataframe=df_tema,
    tabela='tema',
    colunas_tabela=colunas_tabela_tema,
    colunas_dataframe=colunas_dataframe_tema
)

df_links = pd.DataFrame(
  data=[
      {
          'idTema': 14,
          'titulo': '7 argumentos a favor e contra a redução da maioridade penal - Politize!',
          'url': 'http://www.politize.com.br/reducao-da-maioridade-penal-argumentos/',
          'shortUrl': 'http://bit.ly/2MvrCOC',
      },
      {
          'idTema': 14,
          'titulo': 'Entenda de vez o que pode mudar na maioridade penal | EXAME',
          'url': 'https://exame.abril.com.br/brasil/entenda-de-vez-o-que-pode-mudar-na-maioridade-penal/',
          'shortUrl': 'https://abr.ai/2Lq9yQo',
      },
      {
          'idTema': 14,
          'titulo': 'Redução da Maioridade Penal - Debate | Canal Futura - YouTube',
          'url': 'https://www.youtube.com/watch?v=AuRyoAmTPp0',
          'shortUrl': 'http://bit.ly/2wl8lWf',
      },
  ],
  columns=colunas_dataframe_tema_link
)
dataframe_to_database(
    dataframe=df_links,
    tabela='tema_link',
    colunas_tabela=colunas_tabela_tema_link,
    colunas_dataframe=colunas_dataframe_tema_link
)
# Out:
# 3 de 3

# %% [markdown]
# ## Segurança - Intervenção Militar no Rio de Janeiro

# %% [markdown]
# Precisamos baixar a proposição detalhada e a votação, mas a API da câmara está indisponível

# %%
# 28 ago 2018

df_i = obter_detalhes(
    endpoint='/proposicoes',
    id=2168064,
    map_response=map_proposicoes
)

# %%
df_i
# Out:
#         id                                                uri siglaTipo  \
# 0  2168064  https://dadosabertos.camara.leg.br/api/v2/prop...       PDC
#
#    idTipo  numero   ano                                             ementa  \
# 0     135     886  2018  Aprova a intervenção federal no Estado do Rio ...
#
#    dataApresentacao uriOrgaoNumerador uriUltimoRelator      ...       \
# 0  2018-02-19T22:58              None             None      ...
#
#                     descricaoTipo  ementaDetalhada  \
# 0  Projeto de Decreto Legislativo
#
#                                             keywords uriPropPrincipal  \
# 0  Aprovação, Intervenção federal, Rio de Janeiro...             None
#
#   uriPropAnterior uriPropPosterior  \
# 0            None             None
#
#                                       urlInteiroTeor urnFinal  texto  \
# 0  http://www.camara.gov.br/proposicoesWeb/prop_m...     None   None
#
#   justificativa
# 0          None
#
# [1 rows x 32 columns]

# %%
df_i[[
    'id',
    'dataApresentacao',
    'statusProposicao_dataHora',
    'statusProposicao_descricaoTramitacao',
    'statusProposicao_descricaoSituacao',
    'keywords',
    'urlInteiroTeor'
]]
# Out:
#         id  dataApresentacao statusProposicao_dataHora  \
# 0  2168064  2018-02-19T22:58          2018-02-22T00:00
#
#   statusProposicao_descricaoTramitacao statusProposicao_descricaoSituacao  \
# 0                          Recebimento     Transformado em Norma Jurídica
#
#                                             keywords  \
# 0  Aprovação, Intervenção federal, Rio de Janeiro...
#
#                                       urlInteiroTeor
# 0  http://www.camara.gov.br/proposicoesWeb/prop_m...

# %%
df_i[[
    'id',
    'dataApresentacao',
    'statusProposicao_dataHora',
    'statusProposicao_descricaoTramitacao',
    'statusProposicao_descricaoSituacao',
    'keywords',
    'urlInteiroTeor'
]]
# Out:
#         id  dataApresentacao statusProposicao_dataHora  \
# 0  2168064  2018-02-19T22:58          2018-02-22T00:00
#
#   statusProposicao_descricaoTramitacao statusProposicao_descricaoSituacao  \
# 0                          Recebimento     Transformado em Norma Jurídica
#
#                                             keywords  \
# 0  Aprovação, Intervenção federal, Rio de Janeiro...
#
#                                       urlInteiroTeor
# 0  http://www.camara.gov.br/proposicoesWeb/prop_m...

# %%
dataframe_to_database(
    dataframe=df_i,
    tabela='camara_proposicao_detalhada',
    colunas_tabela=[
        'id',
        'data_apresentacao',
        'data_ultimo_status',
        'descricao_tramitacao',
        'descricao_situacao',
        'keywords',
        'url_integra'
    ],
    colunas_dataframe=[
        'id',
        'dataApresentacao',
        'statusProposicao_dataHora',
        'statusProposicao_descricaoTramitacao',
        'statusProposicao_descricaoSituacao',
        'keywords',
        'urlInteiroTeor'
    ]
)
# Out:
# 1 de 1

# %%
df_tema = pd.DataFrame(
    data=[{
        'id': 15,
        'idCategoria': 5,
        'titulo': 'Intervenção Federal (Militar) no Rio de Janeiro',
        'descricao': 'Durante a intervenção, o general responsável só presta contas ao presidente da República e tem liberdade para admitir, demitir, reestruturar órgãos públicos, efetuar gastos, contratar serviços e dar ordens a funcionários civis e militares, sem prestar contas ao governador ou a qualquer outra autoridade estadual.',
        'origemImprensa': False,
        'idProposicaoCamara': 2168064,
        'idVotacaoProposicaoCamara': 8175,
        'idProposicaoSenado': None,
        'idVotacaoProposicaoSenado': None,
    }],
    columns=colunas_dataframe_tema
)
dataframe_to_database(
    dataframe=df_tema,
    tabela='tema',
    colunas_tabela=colunas_tabela_tema,
    colunas_dataframe=colunas_dataframe_tema
)

df_links = pd.DataFrame(
  data=[
      {
          'idTema': 15,
          'titulo': 'Intervenção federal no Rio: as justificativas e as contestações - Nexo Jornal',
          'url': 'https://www.nexojornal.com.br/expresso/2018/02/16/Interven%C3%A7%C3%A3o-federal-no-Rio-as-justificativas-e-as-contesta%C3%A7%C3%B5es',
          'shortUrl': 'http://bit.ly/2o9mr8j',
      },
      {
          'idTema': 15,
          'titulo': 'Tire suas dúvidas sobre a intervenção na segurança pública no Rio de Janeiro - Cotidiano - Folha',
          'url': 'https://www1.folha.uol.com.br/cotidiano/2018/02/tire-suas-duvidas-sobre-a-intervencao-na-seguranca-publica-no-rio-de-janeiro.shtml',
          'shortUrl': 'http://bit.ly/2MuLZLM',
      },
      {
          'idTema': 15,
          'titulo': 'Congresso aprova decreto de intervenção federal no Rio de Janeiro; entenda o que a medida significa - BBC News Brasil',
          'url': 'https://www.bbc.com/portuguese/brasil-43079114',
          'shortUrl': 'https://bbc.in/2P26eNN',
      },
  ],
  columns=colunas_dataframe_tema_link
)
dataframe_to_database(
    dataframe=df_links,
    tabela='tema_link',
    colunas_tabela=colunas_tabela_tema_link,
    colunas_dataframe=colunas_dataframe_tema_link
)
# Out:
# 3 de 3

# %% [markdown]
# ## Proteção Social - Descriminalização do Aborto

# %%
df_tema = pd.DataFrame(
    data=[{
        'id': 16,
        'idCategoria': 3,
        'titulo': 'Descriminalização do Aborto',
        'descricao': 'A discussão passa por definir se o aborto deve ser visto como um problema de saúde pública, se o direito de decidir sobre o próprio corpo no caso de uma gestação é garantido pela Constituição, e se tratar a interrupção da gravidez como crime é ou não uma medida eficiente para evitar a prática do aborto e, ao mesmo tempo, proteger a vida das mulheres.',
        'origemImprensa': True,
        'idProposicaoCamara': None,
        'idVotacaoProposicaoCamara': None,
        'idProposicaoSenado': None,
        'idVotacaoProposicaoSenado': None,
    }],
    columns=colunas_dataframe_tema
)
dataframe_to_database(
    dataframe=df_tema,
    tabela='tema',
    colunas_tabela=colunas_tabela_tema,
    colunas_dataframe=colunas_dataframe_tema
)

df_links = pd.DataFrame(
  data=[
      {
          'idTema': 16,
          'titulo': 'Descriminalização do aborto: quem são os grupos que tentarão influenciar decisão do STF - BBC News Brasil',
          'url': 'https://www.bbc.com/portuguese/brasil-45052975',
          'shortUrl': 'https://bbc.in/2PFMUag',
      },
      {
          'idTema': 16,
          'titulo': 'Descriminalização do aborto divide especialistas em audiência no STF | Agência Brasil',
          'url': 'http://agenciabrasil.ebc.com.br/justica/noticia/2018-08/descriminalizacao-do-aborto-divide-especialistas-em-audiencia-no-stf',
          'shortUrl': 'http://bit.ly/2Nmr22e',
      },
      {
          'idTema': 16,
          'titulo': 'Aborto: argumentos contra e a favor da descriminalização - Jornal Opção',
          'url': 'https://www.jornalopcao.com.br/reportagens/aborto-argumentos-contra-e-a-favor-da-descriminalizacao-134133/',
          'shortUrl': 'http://bit.ly/2MTE1vg',
      },
  ],
  columns=colunas_dataframe_tema_link
)
dataframe_to_database(
    dataframe=df_links,
    tabela='tema_link',
    colunas_tabela=colunas_tabela_tema_link,
    colunas_dataframe=colunas_dataframe_tema_link
)
# Out:
# 3 de 3

# %% [markdown]
# ## Proteção Social - Descriminalização das Drogas

# %%
df_tema = pd.DataFrame(
    data=[{
        'id': 17,
        'idCategoria': 3,
        'titulo': 'Descriminalização das Drogas',
        'descricao': 'A descriminalização das drogas consiste em não punir penalmente os usuários que consumam substâncias consideradas nocivas à saúde. Descriminalizar é retirar a matéria do âmbito penal; é fazer com que a conduta seja tratada de outra forma que não seja a criminal.',
        'origemImprensa': True,
        'idProposicaoCamara': None,
        'idVotacaoProposicaoCamara': None,
        'idProposicaoSenado': None,
        'idVotacaoProposicaoSenado': None,
    }],
    columns=colunas_dataframe_tema
)
dataframe_to_database(
    dataframe=df_tema,
    tabela='tema',
    colunas_tabela=colunas_tabela_tema,
    colunas_dataframe=colunas_dataframe_tema
)

df_links = pd.DataFrame(
  data=[
      {
          'idTema': 17,
          'titulo': 'Lei de Drogas: a distinção entre usuário e traficante, o impacto nas prisões e o debate no país - Nexo Jornal',
          'url': 'https://www.nexojornal.com.br/explicado/2017/01/14/Lei-de-Drogas-a-distin%C3%A7%C3%A3o-entre-usu%C3%A1rio-e-traficante-o-impacto-nas-pris%C3%B5es-e-o-debate-no-pa%C3%ADs',
          'shortUrl': 'http://bit.ly/2wp1kms',
      },
      {
          'idTema': 17,
          'titulo': 'Descriminalização da Drogas: o que é, história e no Brasil - Toda Matéria',
          'url': 'https://www.todamateria.com.br/descriminalizacao-das-drogas/',
          'shortUrl': 'http://bit.ly/2BKgPek',
      },
      {
          'idTema': 17,
          'titulo': 'Descriminalização das Drogas- Observatório da Imprensa - YouTube',
          'url': 'https://www.youtube.com/watch?v=t2sjRowJ-oc',
          'shortUrl': 'http://bit.ly/2weDYAu',
      },
  ],
  columns=colunas_dataframe_tema_link
)
dataframe_to_database(
    dataframe=df_links,
    tabela='tema_link',
    colunas_tabela=colunas_tabela_tema_link,
    colunas_dataframe=colunas_dataframe_tema_link
)
# Out:
# 3 de 3
