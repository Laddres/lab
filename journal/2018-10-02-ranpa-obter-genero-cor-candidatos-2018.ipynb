# %% [markdown]
# # 02 out 2018

# %% [markdown]
# Vamos atualizar nossa base para obter os dados a respeito de gênero e cor/raça dos candidatos às eleições de 2018

# %%
import pandas as pd
import numpy as np
import requests
import sys
import os
import glob
import time

# %%
from utils.dataframe_to_database import dataframe_to_database
from utils.dataframe_to_file import dataframe_to_file
from utils.database_to_dataframe import database_to_dataframe
from utils.download import download
from utils.tse_data_headers import get_header
from utils.tse_migrar_dados_por_estado_2018 import migrar_dados

# %%
header_2018 = get_header(2018)

# %%
header_2018
# Out:
# ['DT_GERACAO',
#  'HH_GERACAO',
#  'ANO_ELEICAO',
#  'CD_TIPO_ELEICAO',
#  'NM_TIPO_ELEICAO',
#  'NR_TURNO',
#  'CD_ELEICAO',
#  'DS_ELEICAO',
#  'DT_ELEICAO',
#  'TP_ABRANGENCIA',
#  'SG_UF',
#  'SG_UE',
#  'NM_UE',
#  'CD_CARGO',
#  'DS_CARGO',
#  'SQ_CANDIDATO',
#  'NR_CANDIDATO',
#  'NM_CANDIDATO',
#  'NM_URNA_CANDIDATO',
#  'NM_SOCIAL_CANDIDATO',
#  'NR_CPF_CANDIDATO',
#  'NM_EMAIL',
#  'CD_SITUACAO_CANDIDATURA',
#  'DS_SITUACAO_CANDIDATURA',
#  'CD_DETALHE_SITUACAO_CAND',
#  'DS_DETALHE_SITUACAO_CAND',
#  'TP_AGREMIACAO',
#  'NR_PARTIDO',
#  'SG_PARTIDO',
#  'NM_PARTIDO',
#  'SQ_COLIGACAO',
#  'NM_COLIGACAO',
#  'DS_COMPOSICAO_COLIGACAO',
#  'CD_NACIONALIDADE',
#  'DS_NACIONALIDADE',
#  'SG_UF_NASCIMENTO',
#  'CD_MUNICIPIO_NASCIMENTO',
#  'NM_MUNICIPIO_NASCIMENTO',
#  'DT_NASCIMENTO',
#  'NR_IDADE_DATA_POSSE',
#  'NR_TITULO_ELEITORAL_CANDIDATO',
#  'CD_GENERO',
#  'DS_GENERO',
#  'CD_GRAU_INSTRUCAO',
#  'DS_GRAU_INSTRUCAO',
#  'CD_ESTADO_CIVIL',
#  'DS_ESTADO_CIVIL',
#  'CD_COR_RACA',
#  'DS_COR_RACA',
#  'CD_OCUPACAO',
#  'DS_OCUPACAO',
#  'NR_DESPESA_MAX_CAMPANHA',
#  'CD_SIT_TOT_TURNO',
#  'DS_SIT_TOT_TURNO',
#  'ST_REELEICAO',
#  'ST_DECLARAR_BENS',
#  'NR_PROTOCOLO_CANDIDATURA',
#  'NR_PROCESSO']

# %%
PREFIXO_ARQUIVO_CANDIDATURAS = 'consulta_cand_'
DIRETORIO_TEMPORARIO = os.path.join('../temp')

def gerar_dataset():
    tempo_inicio_ano = time.time()

    arquivos = PREFIXO_ARQUIVO_CANDIDATURAS + '2018' + '*.csv'
    pathes = os.path.join(DIRETORIO_TEMPORARIO, arquivos)
    arquivos_do_ano = sorted(glob.glob(pathes))

    df_global = pd.DataFrame()
    for arquivo_estado in arquivos_do_ano:
        print('Iniciando {}'.format(arquivo_estado))

        df_estado = pd.read_csv(
            arquivo_estado,
            sep = ';',
            header = 0,
            dtype = np.str,
            names = header_2018,
            encoding = 'iso-8859-1'
        )
        df_global = df_global.append(df_estado)

    return df_global

# %%
df = gerar_dataset()
# Out:
# Iniciando ../temp\consulta_cand_2018_AC.csv
# Iniciando ../temp\consulta_cand_2018_AL.csv
# Iniciando ../temp\consulta_cand_2018_AM.csv
# Iniciando ../temp\consulta_cand_2018_AP.csv
# Iniciando ../temp\consulta_cand_2018_BA.csv
# Iniciando ../temp\consulta_cand_2018_BR.csv
# Iniciando ../temp\consulta_cand_2018_CE.csv
# Iniciando ../temp\consulta_cand_2018_DF.csv
# Iniciando ../temp\consulta_cand_2018_ES.csv
# Iniciando ../temp\consulta_cand_2018_GO.csv
# Iniciando ../temp\consulta_cand_2018_MA.csv
# Iniciando ../temp\consulta_cand_2018_MG.csv
# Iniciando ../temp\consulta_cand_2018_MS.csv
# Iniciando ../temp\consulta_cand_2018_MT.csv
# Iniciando ../temp\consulta_cand_2018_PA.csv
# Iniciando ../temp\consulta_cand_2018_PB.csv
# Iniciando ../temp\consulta_cand_2018_PE.csv
# Iniciando ../temp\consulta_cand_2018_PI.csv
# Iniciando ../temp\consulta_cand_2018_PR.csv
# Iniciando ../temp\consulta_cand_2018_RJ.csv
# Iniciando ../temp\consulta_cand_2018_RN.csv
# Iniciando ../temp\consulta_cand_2018_RO.csv
# Iniciando ../temp\consulta_cand_2018_RR.csv
# Iniciando ../temp\consulta_cand_2018_RS.csv
# Iniciando ../temp\consulta_cand_2018_SC.csv
# Iniciando ../temp\consulta_cand_2018_SE.csv
# Iniciando ../temp\consulta_cand_2018_SP.csv
# Iniciando ../temp\consulta_cand_2018_TO.csv

# %%
df
# Out:
#      DT_GERACAO HH_GERACAO ANO_ELEICAO CD_TIPO_ELEICAO    NM_TIPO_ELEICAO  \
# 0    22/09/2018   14:01:02        2018               2  ELEIÇÃO ORDINÁRIA
# 1    22/09/2018   14:01:02        2018               2  ELEIÇÃO ORDINÁRIA
# 2    22/09/2018   14:01:02        2018               2  ELEIÇÃO ORDINÁRIA
# 3    22/09/2018   14:01:02        2018               2  ELEIÇÃO ORDINÁRIA
# 4    22/09/2018   14:01:02        2018               2  ELEIÇÃO ORDINÁRIA
# 5    22/09/2018   14:01:02        2018               2  ELEIÇÃO ORDINÁRIA
# 6    22/09/2018   14:01:02        2018               2  ELEIÇÃO ORDINÁRIA
# 7    22/09/2018   14:01:02        2018               2  ELEIÇÃO ORDINÁRIA
# 8    22/09/2018   14:01:02        2018               2  ELEIÇÃO ORDINÁRIA
# 9    22/09/2018   14:01:02        2018               2  ELEIÇÃO ORDINÁRIA
# 10   22/09/2018   14:01:02        2018               2  ELEIÇÃO ORDINÁRIA
# 11   22/09/2018   14:01:02        2018               2  ELEIÇÃO ORDINÁRIA
# 12   22/09/2018   14:01:02        2018               2  ELEIÇÃO ORDINÁRIA
# 13   22/09/2018   14:01:02        2018               2  ELEIÇÃO ORDINÁRIA
# 14   22/09/2018   14:01:02        2018               2  ELEIÇÃO ORDINÁRIA
# 15   22/09/2018   14:01:02        2018               2  ELEIÇÃO ORDINÁRIA
# 16   22/09/2018   14:01:02        2018               2  ELEIÇÃO ORDINÁRIA
# 17   22/09/2018   14:01:02        2018               2  ELEIÇÃO ORDINÁRIA
# 18   22/09/2018   14:01:02        2018               2  ELEIÇÃO ORDINÁRIA
# 19   22/09/2018   14:01:02        2018               2  ELEIÇÃO ORDINÁRIA
# 20   22/09/2018   14:01:02        2018               2  ELEIÇÃO ORDINÁRIA
# 21   22/09/2018   14:01:02        2018               2  ELEIÇÃO ORDINÁRIA
# 22   22/09/2018   14:01:02        2018               2  ELEIÇÃO ORDINÁRIA
# 23   22/09/2018   14:01:02        2018               2  ELEIÇÃO ORDINÁRIA
# 24   22/09/2018   14:01:02        2018               2  ELEIÇÃO ORDINÁRIA
# 25   22/09/2018   14:01:02        2018               2  ELEIÇÃO ORDINÁRIA
# 26   22/09/2018   14:01:02        2018               2  ELEIÇÃO ORDINÁRIA
# 27   22/09/2018   14:01:02        2018               2  ELEIÇÃO ORDINÁRIA
# 28   22/09/2018   14:01:02        2018               2  ELEIÇÃO ORDINÁRIA
# 29   22/09/2018   14:01:02        2018               2  ELEIÇÃO ORDINÁRIA
# ..          ...        ...         ...             ...                ...
# 334  22/09/2018   14:01:02        2018               2  ELEIÇÃO ORDINÁRIA
# 335  22/09/2018   14:01:02        2018               2  ELEIÇÃO ORDINÁRIA
# 336  22/09/2018   14:01:02        2018               2  ELEIÇÃO ORDINÁRIA
# 337  22/09/2018   14:01:02        2018               2  ELEIÇÃO ORDINÁRIA
# 338  22/09/2018   14:01:02        2018               2  ELEIÇÃO ORDINÁRIA
# 339  22/09/2018   14:01:02        2018               2  ELEIÇÃO ORDINÁRIA
# 340  22/09/2018   14:01:02        2018               2  ELEIÇÃO ORDINÁRIA
# 341  22/09/2018   14:01:02        2018               2  ELEIÇÃO ORDINÁRIA
# 342  22/09/2018   14:01:02        2018               2  ELEIÇÃO ORDINÁRIA
# 343  22/09/2018   14:01:02        2018               2  ELEIÇÃO ORDINÁRIA
# 344  22/09/2018   14:01:02        2018               2  ELEIÇÃO ORDINÁRIA
# 345  22/09/2018   14:01:02        2018               2  ELEIÇÃO ORDINÁRIA
# 346  22/09/2018   14:01:02        2018               2  ELEIÇÃO ORDINÁRIA
# 347  22/09/2018   14:01:02        2018               2  ELEIÇÃO ORDINÁRIA
# 348  22/09/2018   14:01:02        2018               2  ELEIÇÃO ORDINÁRIA
# 349  22/09/2018   14:01:02        2018               2  ELEIÇÃO ORDINÁRIA
# 350  22/09/2018   14:01:02        2018               2  ELEIÇÃO ORDINÁRIA
# 351  22/09/2018   14:01:02        2018               2  ELEIÇÃO ORDINÁRIA
# 352  22/09/2018   14:01:02        2018               2  ELEIÇÃO ORDINÁRIA
# 353  22/09/2018   14:01:02        2018               2  ELEIÇÃO ORDINÁRIA
# 354  22/09/2018   14:01:02        2018               2  ELEIÇÃO ORDINÁRIA
# 355  22/09/2018   14:01:02        2018               2  ELEIÇÃO ORDINÁRIA
# 356  22/09/2018   14:01:02        2018               2  ELEIÇÃO ORDINÁRIA
# 357  22/09/2018   14:01:02        2018               2  ELEIÇÃO ORDINÁRIA
# 358  22/09/2018   14:01:02        2018               2  ELEIÇÃO ORDINÁRIA
# 359  22/09/2018   14:01:02        2018               2  ELEIÇÃO ORDINÁRIA
# 360  22/09/2018   14:01:02        2018               2  ELEIÇÃO ORDINÁRIA
# 361  22/09/2018   14:01:02        2018               2  ELEIÇÃO ORDINÁRIA
# 362  22/09/2018   14:01:02        2018               2  ELEIÇÃO ORDINÁRIA
# 363  22/09/2018   14:01:02        2018               2  ELEIÇÃO ORDINÁRIA
#
#     NR_TURNO CD_ELEICAO                      DS_ELEICAO  DT_ELEICAO  \
# 0          1        297  Eleições Gerais Estaduais 2018  07/10/2018
# 1          1        297  Eleições Gerais Estaduais 2018  07/10/2018
# 2          1        297  Eleições Gerais Estaduais 2018  07/10/2018
# 3          1        297  Eleições Gerais Estaduais 2018  07/10/2018
# 4          1        297  Eleições Gerais Estaduais 2018  07/10/2018
# 5          1        297  Eleições Gerais Estaduais 2018  07/10/2018
# 6          1        297  Eleições Gerais Estaduais 2018  07/10/2018
# 7          1        297  Eleições Gerais Estaduais 2018  07/10/2018
# 8          1        297  Eleições Gerais Estaduais 2018  07/10/2018
# 9          1        297  Eleições Gerais Estaduais 2018  07/10/2018
# 10         1        297  Eleições Gerais Estaduais 2018  07/10/2018
# 11         1        297  Eleições Gerais Estaduais 2018  07/10/2018
# 12         1        297  Eleições Gerais Estaduais 2018  07/10/2018
# 13         1        297  Eleições Gerais Estaduais 2018  07/10/2018
# 14         1        297  Eleições Gerais Estaduais 2018  07/10/2018
# 15         1        297  Eleições Gerais Estaduais 2018  07/10/2018
# 16         1        297  Eleições Gerais Estaduais 2018  07/10/2018
# 17         1        297  Eleições Gerais Estaduais 2018  07/10/2018
# 18         1        297  Eleições Gerais Estaduais 2018  07/10/2018
# 19         1        297  Eleições Gerais Estaduais 2018  07/10/2018
# 20         1        297  Eleições Gerais Estaduais 2018  07/10/2018
# 21         1        297  Eleições Gerais Estaduais 2018  07/10/2018
# 22         1        297  Eleições Gerais Estaduais 2018  07/10/2018
# 23         1        297  Eleições Gerais Estaduais 2018  07/10/2018
# 24         1        297  Eleições Gerais Estaduais 2018  07/10/2018
# 25         1        297  Eleições Gerais Estaduais 2018  07/10/2018
# 26         1        297  Eleições Gerais Estaduais 2018  07/10/2018
# 27         1        297  Eleições Gerais Estaduais 2018  07/10/2018
# 28         1        297  Eleições Gerais Estaduais 2018  07/10/2018
# 29         1        297  Eleições Gerais Estaduais 2018  07/10/2018
# ..       ...        ...                             ...         ...
# 334        1        297  Eleições Gerais Estaduais 2018  07/10/2018
# 335        1        297  Eleições Gerais Estaduais 2018  07/10/2018
# 336        1        297  Eleições Gerais Estaduais 2018  07/10/2018
# 337        1        297  Eleições Gerais Estaduais 2018  07/10/2018
# 338        1        297  Eleições Gerais Estaduais 2018  07/10/2018
# 339        1        297  Eleições Gerais Estaduais 2018  07/10/2018
# 340        1        297  Eleições Gerais Estaduais 2018  07/10/2018
# 341        1        297  Eleições Gerais Estaduais 2018  07/10/2018
# 342        1        297  Eleições Gerais Estaduais 2018  07/10/2018
# 343        1        297  Eleições Gerais Estaduais 2018  07/10/2018
# 344        1        297  Eleições Gerais Estaduais 2018  07/10/2018
# 345        1        297  Eleições Gerais Estaduais 2018  07/10/2018
# 346        1        297  Eleições Gerais Estaduais 2018  07/10/2018
# 347        1        297  Eleições Gerais Estaduais 2018  07/10/2018
# 348        1        297  Eleições Gerais Estaduais 2018  07/10/2018
# 349        1        297  Eleições Gerais Estaduais 2018  07/10/2018
# 350        1        297  Eleições Gerais Estaduais 2018  07/10/2018
# 351        1        297  Eleições Gerais Estaduais 2018  07/10/2018
# 352        1        297  Eleições Gerais Estaduais 2018  07/10/2018
# 353        1        297  Eleições Gerais Estaduais 2018  07/10/2018
# 354        1        297  Eleições Gerais Estaduais 2018  07/10/2018
# 355        1        297  Eleições Gerais Estaduais 2018  07/10/2018
# 356        1        297  Eleições Gerais Estaduais 2018  07/10/2018
# 357        1        297  Eleições Gerais Estaduais 2018  07/10/2018
# 358        1        297  Eleições Gerais Estaduais 2018  07/10/2018
# 359        1        297  Eleições Gerais Estaduais 2018  07/10/2018
# 360        1        297  Eleições Gerais Estaduais 2018  07/10/2018
# 361        1        297  Eleições Gerais Estaduais 2018  07/10/2018
# 362        1        297  Eleições Gerais Estaduais 2018  07/10/2018
# 363        1        297  Eleições Gerais Estaduais 2018  07/10/2018
#
#     TP_ABRANGENCIA          ...          DS_COR_RACA CD_OCUPACAO  \
# 0         ESTADUAL          ...                PARDA         257
# 1         ESTADUAL          ...                PARDA         999
# 2         ESTADUAL          ...               BRANCA         999
# 3         ESTADUAL          ...                PARDA         999
# 4         ESTADUAL          ...                PARDA         503
# 5         ESTADUAL          ...                PARDA         298
# 6         ESTADUAL          ...                PARDA         999
# 7         ESTADUAL          ...                PARDA         999
# 8         ESTADUAL          ...                PARDA         395
# 9         ESTADUAL          ...                PARDA         999
# 10        ESTADUAL          ...               BRANCA         999
# 11        ESTADUAL          ...                PARDA         303
# 12        ESTADUAL          ...                PARDA         999
# 13        ESTADUAL          ...                PARDA         298
# 14        ESTADUAL          ...                PARDA         233
# 15        ESTADUAL          ...                PARDA         999
# 16        ESTADUAL          ...                PARDA         999
# 17        ESTADUAL          ...                PRETA         999
# 18        ESTADUAL          ...                PARDA         999
# 19        ESTADUAL          ...               BRANCA         278
# 20        ESTADUAL          ...                PRETA         131
# 21        ESTADUAL          ...                PARDA         276
# 22        ESTADUAL          ...                PARDA         233
# 23        ESTADUAL          ...                PARDA         292
# 24        ESTADUAL          ...                PARDA         999
# 25        ESTADUAL          ...                PARDA         999
# 26        ESTADUAL          ...                PARDA         999
# 27        ESTADUAL          ...                PARDA         999
# 28        ESTADUAL          ...                PARDA         257
# 29        ESTADUAL          ...               BRANCA         999
# ..             ...          ...                  ...         ...
# 334       ESTADUAL          ...               BRANCA         257
# 335       ESTADUAL          ...               BRANCA         296
# 336       ESTADUAL          ...                PRETA         999
# 337       ESTADUAL          ...                PARDA         999
# 338       ESTADUAL          ...               BRANCA         112
# 339       ESTADUAL          ...               BRANCA         999
# 340       ESTADUAL          ...               BRANCA         121
# 341       ESTADUAL          ...               BRANCA         298
# 342       ESTADUAL          ...                PARDA         296
# 343       ESTADUAL          ...               BRANCA         257
# 344       ESTADUAL          ...               BRANCA         257
# 345       ESTADUAL          ...                PARDA         257
# 346       ESTADUAL          ...               BRANCA         923
# 347       ESTADUAL          ...                PARDA         923
# 348       ESTADUAL          ...                PRETA         266
# 349       ESTADUAL          ...                PARDA         263
# 350       ESTADUAL          ...                PARDA         237
# 351       ESTADUAL          ...                PARDA         230
# 352       ESTADUAL          ...                PARDA         602
# 353       ESTADUAL          ...               BRANCA         602
# 354       ESTADUAL          ...                PARDA         921
# 355       ESTADUAL          ...               BRANCA         923
# 356       ESTADUAL          ...                PARDA         278
# 357       ESTADUAL          ...                PARDA         142
# 358       ESTADUAL          ...                PARDA         232
# 359       ESTADUAL          ...               BRANCA         999
# 360       ESTADUAL          ...                PRETA         134
# 361       ESTADUAL          ...                PARDA         278
# 362       ESTADUAL          ...                PARDA         291
# 363       ESTADUAL          ...                PARDA         131
#
#                               DS_OCUPACAO NR_DESPESA_MAX_CAMPANHA  \
# 0                              EMPRESÁRIO                       0
# 1                                  OUTROS                      -1
# 2                                  OUTROS                       0
# 3                                  OUTROS                       0
# 4                               FAXINEIRO                       0
# 5              SERVIDOR PÚBLICO MUNICIPAL                       0
# 6                                  OUTROS                       0
# 7                                  OUTROS                       0
# 8                  BANCÁRIO E ECONOMIÁRIO                       0
# 9                                  OUTROS                       0
# 10                                 OUTROS                       0
# 11                                GERENTE                       0
# 12                                 OUTROS                       0
# 13             SERVIDOR PÚBLICO MUNICIPAL                       0
# 14                       POLICIAL MILITAR                      -1
# 15                                 OUTROS                       0
# 16                                 OUTROS                       0
# 17                                 OUTROS                       0
# 18                                 OUTROS                      -1
# 19                               VEREADOR                      -1
# 20                               ADVOGADO                      -1
# 21                                SENADOR                       0
# 22                       POLICIAL MILITAR                       0
# 23                  AGENTE ADMINISTRATIVO                       0
# 24                                 OUTROS                       0
# 25                                 OUTROS                       0
# 26                                 OUTROS                       0
# 27                                 OUTROS                       0
# 28                             EMPRESÁRIO                       0
# 29                                 OUTROS                       0
# ..                                    ...                     ...
# 334                            EMPRESÁRIO                      -1
# 335              SERVIDOR PÚBLICO FEDERAL                      -1
# 336                                OUTROS                      -1
# 337                                OUTROS                      -1
# 338                           VETERINÁRIO                      -1
# 339                                OUTROS                      -1
# 340                            ECONOMISTA                      -1
# 341            SERVIDOR PÚBLICO MUNICIPAL                      -1
# 342              SERVIDOR PÚBLICO FEDERAL                      -1
# 343                            EMPRESÁRIO                      -1
# 344                            EMPRESÁRIO                      -1
# 345                            EMPRESÁRIO                      -1
# 346  APOSENTADO (EXCETO SERVIDOR PÚBLICO)                      -1
# 347  APOSENTADO (EXCETO SERVIDOR PÚBLICO)                      -1
# 348             PROFESSOR DE ENSINO MÉDIO                      -1
# 349                               BIÓLOGO                      -1
# 350               REPRESENTANTE COMERCIAL                      -1
# 351                              PEDAGOGO                      -1
# 352                            PECUARISTA                      -1
# 353                            PECUARISTA                      -1
# 354                     MILITAR REFORMADO                      -1
# 355  APOSENTADO (EXCETO SERVIDOR PÚBLICO)                      -1
# 356                              VEREADOR                      -1
# 357          PROFESSOR DE ENSINO SUPERIOR                      -1
# 358                        POLICIAL CIVIL                      -1
# 359                                OUTROS                      -1
# 360                     ASSISTENTE SOCIAL                      -1
# 361                              VEREADOR                      -1
# 362         OCUPANTE DE CARGO EM COMISSÃO                      -1
# 363                              ADVOGADO                      -1
#
#     CD_SIT_TOT_TURNO DS_SIT_TOT_TURNO ST_REELEICAO ST_DECLARAR_BENS  \
# 0                 -1           #NULO#            N                N
# 1                 -1           #NULO#            N                N
# 2                 -1           #NULO#            N                S
# 3                 -1           #NULO#            N                S
# 4                 -1           #NULO#            N                N
# 5                 -1           #NULO#            N                S
# 6                 -1           #NULO#            N                N
# 7                 -1           #NULO#            N                N
# 8                 -1           #NULO#            N                S
# 9                 -1           #NULO#            N                N
# 10                -1           #NULO#            N                S
# 11                -1           #NULO#            N                S
# 12                -1           #NULO#            N                S
# 13                -1           #NULO#            N                S
# 14                -1           #NULO#            N                S
# 15                -1           #NULO#            N                S
# 16                -1           #NULO#            N                S
# 17                -1           #NULO#            N                S
# 18                -1           #NULO#            N                N
# 19                -1           #NULO#            N                S
# 20                -1           #NULO#            N                N
# 21                -1           #NULO#            S                S
# 22                -1           #NULO#            N                S
# 23                -1           #NULO#            N                S
# 24                -1           #NULO#            N                N
# 25                -1           #NULO#            N                N
# 26                -1           #NULO#            N                S
# 27                -1           #NULO#            N                N
# 28                -1           #NULO#            N                N
# 29                -1           #NULO#            N                S
# ..               ...              ...          ...              ...
# 334               -1           #NULO#            N                S
# 335               -1           #NULO#            N                N
# 336               -1           #NULO#            N                S
# 337               -1           #NULO#            S                S
# 338               -1           #NULO#            N                S
# 339               -1           #NULO#            N                S
# 340               -1           #NULO#            N                N
# 341               -1           #NULO#            N                S
# 342               -1           #NULO#            S                S
# 343               -1           #NULO#            N                S
# 344               -1           #NULO#            N                S
# 345               -1           #NULO#            N                S
# 346               -1           #NULO#            N                N
# 347               -1           #NULO#            N                N
# 348               -1           #NULO#            N                S
# 349               -1           #NULO#            N                S
# 350               -1           #NULO#            N                S
# 351               -1           #NULO#            N                S
# 352               -1           #NULO#            N                S
# 353               -1           #NULO#            N                S
# 354               -1           #NULO#            N                S
# 355               -1           #NULO#            N                S
# 356               -1           #NULO#            N                S
# 357               -1           #NULO#            N                S
# 358               -1           #NULO#            N                S
# 359               -1           #NULO#            N                S
# 360               -1           #NULO#            N                S
# 361               -1           #NULO#            N                S
# 362               -1           #NULO#            N                S
# 363               -1           #NULO#            S                S
#
#     NR_PROTOCOLO_CANDIDATURA           NR_PROCESSO
# 0                         -1  06007352120186010000
# 1                         -1  06007586420186010000
# 2                         -1  06005412120186010000
# 3                         -1  06005931720186010000
# 4                         -1  06004060920186010000
# 5                         -1  06003576520186010000
# 6                         -1  06001653520186010000
# 7                         -1  06006226720186010000
# 8                         -1  06005958420186010000
# 9                         -1  06001385220186010000
# 10                        -1  06007014620186010000
# 11                        -1  06006599420186010000
# 12                        -1  06003671220186010000
# 13                        -1  06004797820186010000
# 14                        -1  06003897020186010000
# 15                        -1  06004936220186010000
# 16                        -1  06006771820186010000
# 17                        -1  06002537320186010000
# 18                        -1  06004607220186010000
# 19                        -1  06005889220186010000
# 20                        -1  06006365120186010000
# 21                        -1  06006434320186010000
# 22                        -1  06006859220186010000
# 23                        -1  06002562820186010000
# 24                        -1  06007006120186010000
# 25                        -1  06003073920186010000
# 26                        -1  06006607920186010000
# 27                        -1  06001749420186010000
# 28                        -1  06001896320186010000
# 29                        -1  06002900320186010000
# ..                       ...                   ...
# 334                       -1  06004743320186270000
# 335                       -1  06008078220186270000
# 336                       -1  06012737620186270000
# 337                       -1  06005470520186270000
# 338                       -1  06004916920186270000
# 339                       -1  06005549420186270000
# 340                       -1  06008398720186270000
# 341                       -1  06008883120186270000
# 342                       -1  06006224420186270000
# 343                       -1  06008043020186270000
# 344                       -1  06004682620186270000
# 345                       -1  06007636320186270000
# 346                       -1  06009169620186270000
# 347                       -1  06007280620186270000
# 348                       -1  06005124520186270000
# 349                       -1  06008086720186270000
# 350                       -1  06005817720186270000
# 351                       -1  06005099020186270000
# 352                       -1  06007592620186270000
# 353                       -1  06008009020186270000
# 354                       -1  06008172920186270000
# 355                       -1  06006232920186270000
# 356                       -1  06005141520186270000
# 357                       -1  06007982320186270000
# 358                       -1  06008614820186270000
# 359                       -1  06006016820186270000
# 360                       -1  06005159720186270000
# 361                       -1  06004881720186270000
# 362                       -1  06008788420186270000
# 363                       -1  06005306620186270000
#
# [29098 rows x 58 columns]

# %%
dataframe_to_file(
    dataframe=df,
    origem_dados='tse',
    nome='candidaturas-2018'
)

# %% [markdown]
# ## Gêneros

# %%
generos = (
    df[[
        'CD_GENERO',
        'DS_GENERO'
    ]]
    .drop_duplicates('CD_GENERO', keep='last')
    .sort_values(by=['CD_GENERO'], ascending=True, na_position='first')
    .rename(columns = {
        'CD_GENERO': 'codigo_tse',
        'DS_GENERO': 'descricao'
    })
)

generos.index = generos.reset_index().index

generos
# Out:
#   codigo_tse  descricao
# 0          2  MASCULINO
# 1          4   FEMININO

# %% [markdown]
# ### Tabela de Gênero

# %% [markdown]
# ```SQL
# -- -----------------------------------------------------
# -- Table `laddres`.`genero`
# -- -----------------------------------------------------
# CREATE TABLE IF NOT EXISTS `laddres`.`genero` (
#   `id` INT NOT NULL,
#   `descricao` VARCHAR(20) NOT NULL,
#   PRIMARY KEY (`id`))
# ENGINE = InnoDB;
#
#
# ALTER TABLE candidato ADD genero_id INT NULL;
# ALTER TABLE candidato ADD CONSTRAINT fk_candidato_genero1 FOREIGN KEY (`genero_id`) REFERENCES `laddres`.`genero` (`id`) ON DELETE NO ACTION ON UPDATE NO ACTION;
# ```

# %% [markdown]
# ### Salvar Dados

# %%
dataframe_to_database(
    dataframe=generos,
    tabela='genero',
    colunas_tabela=['id', 'descricao'],
    colunas_dataframe=['codigo_tse', 'descricao']
)
# Out:
# 361 de 2

# %% [markdown]
# ## Analisar Cor/Raça

# %%
cores = (
    df[[
        'CD_COR_RACA',
        'DS_COR_RACA'
    ]]
    .drop_duplicates('CD_COR_RACA', keep='last')
    .sort_values(by=['CD_COR_RACA'], ascending=True, na_position='first')
    .rename(columns = {
        'CD_COR_RACA': 'codigo_tse',
        'DS_COR_RACA': 'descricao'
    })
)

cores.index = cores.reset_index().index

cores
# Out:
#   codigo_tse descricao
# 0         01    BRANCA
# 1         02     PRETA
# 2         03     PARDA
# 3         04   AMARELA
# 4         05  INDÍGENA

# %% [markdown]
# ### Tabela de Cor/Raça

# %% [markdown]
# ```SQL
# -- -----------------------------------------------------
# -- Table `laddres`.`cor_raca`
# -- -----------------------------------------------------
# CREATE TABLE IF NOT EXISTS `laddres`.`cor_raca` (
#   `id` INT NOT NULL,
#   `descricao` VARCHAR(20) NOT NULL,
#   PRIMARY KEY (`id`))
# ENGINE = InnoDB;
#
#
# ALTER TABLE candidato ADD cor_raca_id INT NULL;
# ALTER TABLE candidato ADD CONSTRAINT fk_candidato_cor_raca1 FOREIGN KEY (`cor_raca_id`) REFERENCES `laddres`.`cor_raca` (`id`) ON DELETE NO ACTION ON UPDATE NO ACTION;
# ```

# %% [markdown]
# ### Salvar Dados

# %%
dataframe_to_database(
    dataframe=cores,
    tabela='cor_raca',
    colunas_tabela=['id', 'descricao'],
    colunas_dataframe=['codigo_tse', 'descricao']
)
# Out:
# 230 de 5

# %% [markdown]
# ## Reprocessar Dados

# %% [markdown]
# ```SQL
# DELETE FROM candidatura WHERE eleicao_id = 202;
# DELETE FROM candidatura WHERE eleicao_id = 203;
# ```

# %%
migrar_dados(2018)
# Out:
# Iniciando ../temp\consulta_cand_2018_AC.csv
# Total de candidaturas em 2018: 586
# 586 de 586
# Tempo total desse estado: 6.41s
#
# Iniciando ../temp\consulta_cand_2018_AL.csv
# Total de candidaturas em 2018: 461
# 461 de 461
# Tempo total desse estado: 3.76s
#
# Iniciando ../temp\consulta_cand_2018_AM.csv
# Total de candidaturas em 2018: 855
# 855 de 855
# Tempo total desse estado: 7.03s
#
# Iniciando ../temp\consulta_cand_2018_AP.csv
# Total de candidaturas em 2018: 663
# 663 de 663
# Tempo total desse estado: 5.34s
#
# Iniciando ../temp\consulta_cand_2018_BA.csv
# Total de candidaturas em 2018: 1196
# 1196 de 1196
# Tempo total desse estado: 11.01s
#
# Iniciando ../temp\consulta_cand_2018_BR.csv
# Total de candidaturas em 2018: 28
# 28 de 28
# Tempo total desse estado: 0.22s
#
# Iniciando ../temp\consulta_cand_2018_CE.csv
# Total de candidaturas em 2018: 915
# 915 de 915
# Tempo total desse estado: 7.97s
#
# Iniciando ../temp\consulta_cand_2018_DF.csv
# Total de candidaturas em 2018: 1258
# 1258 de 1258
# Tempo total desse estado: 10.08s
#
# Iniciando ../temp\consulta_cand_2018_ES.csv
# Total de candidaturas em 2018: 833
# 833 de 833
# Tempo total desse estado: 7.04s
#
# Iniciando ../temp\consulta_cand_2018_GO.csv
# Total de candidaturas em 2018: 1190
# 1190 de 1190
# Tempo total desse estado: 10.89s
#
# Iniciando ../temp\consulta_cand_2018_MA.csv
# Total de candidaturas em 2018: 796
# 796 de 796
# Tempo total desse estado: 7.30s
#
# Iniciando ../temp\consulta_cand_2018_MG.csv
# Total de candidaturas em 2018: 2390
# 2390 de 2390
# Tempo total desse estado: 24.59s
#
# Iniciando ../temp\consulta_cand_2018_MS.csv
# Total de candidaturas em 2018: 541
# 541 de 541
# Tempo total desse estado: 4.62s
#
# Iniciando ../temp\consulta_cand_2018_MT.csv
# Total de candidaturas em 2018: 541
# 541 de 541
# Tempo total desse estado: 4.72s
#
# Iniciando ../temp\consulta_cand_2018_PA.csv
# Total de candidaturas em 2018: 899
# 899 de 899
# Tempo total desse estado: 8.00s
#
# Iniciando ../temp\consulta_cand_2018_PB.csv
# Total de candidaturas em 2018: 621
# 621 de 621
# Tempo total desse estado: 5.51s
#
# Iniciando ../temp\consulta_cand_2018_PE.csv
# Total de candidaturas em 2018: 1094
# 1094 de 1094
# Tempo total desse estado: 9.69s
#
# Iniciando ../temp\consulta_cand_2018_PI.csv
# Total de candidaturas em 2018: 439
# 439 de 439
# Tempo total desse estado: 3.96s
#
# Iniciando ../temp\consulta_cand_2018_PR.csv
# Total de candidaturas em 2018: 1288
# 1288 de 1288
# Tempo total desse estado: 12.11s
#
# Iniciando ../temp\consulta_cand_2018_RJ.csv
# Total de candidaturas em 2018: 3695
# 3695 de 3695
# Tempo total desse estado: 35.53s
#
# Iniciando ../temp\consulta_cand_2018_RN.csv
# Total de candidaturas em 2018: 512
# 512 de 512
# Tempo total desse estado: 4.42s
#
# Iniciando ../temp\consulta_cand_2018_RO.csv
# Total de candidaturas em 2018: 654
# 654 de 654
# Tempo total desse estado: 5.77s
#
# Iniciando ../temp\consulta_cand_2018_RR.csv
# Total de candidaturas em 2018: 683
# 683 de 683
# Tempo total desse estado: 5.60s
#
# Iniciando ../temp\consulta_cand_2018_RS.csv
# Total de candidaturas em 2018: 1339
# 1339 de 1339
# Tempo total desse estado: 12.81s
#
# Iniciando ../temp\consulta_cand_2018_SC.csv
# Total de candidaturas em 2018: 783
# 783 de 783
# Tempo total desse estado: 7.15s
#
# Iniciando ../temp\consulta_cand_2018_SE.csv
# Total de candidaturas em 2018: 526
# 526 de 526
# Tempo total desse estado: 4.59s
#
# Iniciando ../temp\consulta_cand_2018_SP.csv
# Total de candidaturas em 2018: 3948
# 3948 de 3948
# Tempo total desse estado: 38.71s
#
# Iniciando ../temp\consulta_cand_2018_TO.csv
# Total de candidaturas em 2018: 364
# 364 de 364
# Tempo total desse estado: 3.30s
#
# Tempo total em 2018: 268.14s
